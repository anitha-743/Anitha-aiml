# %%
crop="rice"
soil_type="black soil"
print(crop)
print(soil_type)
print(crop,soil_type)
# Out:
# rice
# black soil
# rice black soil

# %%
crop="rice",
soil_type="black soil"
print(crop)
print(soil_type)
print(crop,soil_type)
# Out:
# ('rice',)
# black soil
# ('rice',) black soil

# %%
crop="rice"
soil_type="blacksoil"
print(crop,soil_type)
print(len(crop))
print(len(soil_type))
# Out:
# rice blacksoil
# 4
# 9

# %%
crop="rice"
soil_type="black soil"
print(crop,soil_type)
print(len(crop))
print(len(soil_type))
# Out:
# rice black soil
# 4
# 10

# %%
crop_name="groundnut"
print(crop_name[0])
print(crop_name[1])
print(crop_name[2])
print(crop_name[3])
print(crop_name[4])
print(crop_name[5])
print(crop_name[6])
print(crop_name[7])
print(crop_name[8])
print(crop_name[-1])
# Out:
# g
# r
# o
# u
# n
# d
# n
# u
# t
# t

# %%
crop_name="groundnut"
print(crop_name[0:3])
print(crop_name[:5])
print(crop_name[5:])
print(crop_name[0:7:3])
print(crop_name[1:2:5])
print(crop_name[0:3:4])
print(crop_name[:])
print(crop_name[-7])
# Out:
# gro
# groun
# dnut
# gun
# r
# g
# groundnut
# o

# %%
print("rice".upper())
print("WHEAT".lower())
print("green gram".title())
print("cotton crop".capitalize())
# Out:
# RICE
# wheat
# Green Gram
# Cotton crop

# %%
raw_crop="  RICE  "
print(raw_crop.strip())
print(raw_crop.lstrip())
print(raw_crop.rstrip())
# Out:
# RICE
# RICE
#   RICE

# %%
raw_crop="  RICE  "
print(raw_crop.strip())
print("***wheat".lstrip("*"))
print("Maize###".rstrip("#"))
# Out:
# RICE
# wheat
# Maize

# %%
text="organic rice and rice cultivation"
print(text.find("rice"))
print(text.count("rice"))
print("rice"in text)
# Out:
# 8
# 2
# True

# %%
text="organicrice  cultivation"
print(text.find("rice"))
print(text.count("rice"))
print("rice"in text)
# Out:
# 7
# 1
# True

# %%
print("rice".replace("rice","wheat"))
# Out:
# wheat
