# %%
li=['Harsha','Pratik','Bob','Dhruv']
print(li[1][-1])
print(li[2][-1])
# Out:
# k
# b

# %%
def gfg(x,li=[]):
  for i in range(x):
    li.append(i*i)
  print(li)

gfg(3,[3,2,1])
# Out:
# [3, 2, 1, 0, 1, 4]

# %%
a=['Greeks','for','Greeks']
b=[i[0].upper() for i in a]
c=[i[2] for i in a]
d=[i[1].upper()for i in a]
print(b)
print(c)
print(d)
# Out:
# ['G', 'F', 'G']
# ['e', 'r', 'e']
# ['R', 'O', 'R']

# %%
def addToList(a):
  a+=[10]
b=[10,20,30,40]
addToList(b)
print(len(b))
# Out:
# 5

# %%
li=[1,1.33,'GFG',0,'NO','G',None,True]
val1,val2=0,''
for x in li:
  if (type(x)==int or
type(x)==float):
   val1+=x
  elif(type(x)==str):
    val2+=x
  else:
    break
print(val1,val2)
# Out:
# 2.33 GFGNOG

# %%
li=[1,1.33,'GFG',0,'NO',None,'G',True]
val1,val2=0,''
for x in li:
  if (type(x)==int or
type(x)==float):
   val1+=x
  elif(type(x)==str):
    val2+=x
  else:
    break
print(val1,val2)
# Out:
# 2.33 GFGNO

# %%
a=['physics','chemistery','1997',2000]
print(a[1][-1])
print(a[2][-1])
# Out:
# y
# 7

# %%
count=0
while count<3:
  print("Hello")
  count+=1
else:
  print("Else block")
# Out:
# Hello
# Hello
# Hello
# Else block

# %%
for num in range(10,14):
  for i in range(2,num):
    if num%i==1:
      print(num)
      break
# Out:
# 10
# 11
# 12
# 13

# %%
while True:
  print("Greeks!")
  break
# Out:
# Greeks!

# %%
num=10
while num>0:
  if num%2==0:
    print(num,end="")
  num-=1
# Out:
# 108642

# %%
a=[]
a.append([1,[2,3],4])
a.extend([7,8,9])
print(a[0][1][1]+a[2])
# Out:
# 11

# %%
li=range(100,110)

print(li.index(105))
# Out:
# 5

# %%
x="GFG"
for i in range(len(x)):
  print(i)
# Out:
# 0
# 1
# 2
